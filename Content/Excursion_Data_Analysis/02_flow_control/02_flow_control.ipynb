# %% [markdown]
# <div style="width: 100%; overflow: hidden;">
#     <div style="width: 500px; float: left;">
#         <h1>Data Analysis with Python</h1> <br>
#         <b>Winter Semester 2019/2020</b><br>
#         <b>Lukas Arnold, Max Böhler and Linh Würzburger</b>
#     </div>
#     <div style="float:right;">
#         <img src="images/cce_logo.png" style="width:250px;"/>
#         <img src="images/buw_logo.png" style="width:150px;"/><img src="images/fzj_logo.png" style="width:150px;"/>
#     </div>
# </div>

# %% [markdown]
# ## For Loop
#
# `for` loops are traditionally used when you have a block of code which you want to repeat a fixed number of times. The structure of a `for` loop consists of a iteration variable, a set of elements, which will be looped over, and the loop body. The body is the part that will be repeated for each element of the iteration set.
#
# ### Code Blocks
# Many other programming languages use brackets to indicate groups of code, like the body of a for loop. Python used indentations to group lines of code. Use a tab to create new block.
#
# ### Comments
# To add comments to your code, use the `#` character. Every text after it till the end of line will be ignored and not executed.

# %%
# Example 1

# Goal: Print out the numbers 0,1,2
# iteration variable: number
# iteration set: [0,1,2] generated by the range-function
for number in range(3):
    print(number)

# %%
# Example 2

# Print out the elements of the list movies
movies = ["Escape from LA", "Pulp Fiction", "Pumping Iron", 5.5, 2]
for j in movies:
    print(type(j))

# %%
movies = ["Escape from LA", "Pulp Fiction", "Pumping Iron", 5.5, 2, 'Escape from NY']
# 
numbers = [1,2,3,4,5,6]

#print(len(movies))

for i in range(len(movies)-1,-1,-1):
    #print(i)
    print(movies[i], numbers[i])

# %%
movies = ["Escape from LA", "Pulp Fiction", "Pumping Iron", 5.5, 2, 'Escape from NY']
# 
numbers = [1,2,3,4,5,6]

for k in range(0, len(movies)):
    counter = len(movies)-k-1
    print(movies[counter])

# %% [markdown]
# A `for` loop can also be used to read in a text file line by line. Here the iteration set consists out of individual lines of a text file.
# To open a file, use the `open(filename, mode)` function. Mode is eiter `r` (read),`w` (write), or `a` (append to a file). Once finished with the file access, the file should be closed with the `file.close()` function.
#
# ```Python
# # open a file for reading, the file can be accessed via the data_file variable
# data_file = open('data.txt', 'r')
#
# # loop over each line, the content of the current line is stored in the line variable
# for line in data_file:
#     # print the content of the line
#     print(line)
#
# # close the file
# data_file.close()
# ```

# %%
# open a file for reading, the file can be accessed via the data_file variable
data_file = open('data.txt', 'r')

# loop over each line, the content of the current line is stored in the line variable 
for line in data_file:
    # print the content of the line
    print(line)

# close the file
data_file.close()

# %% [markdown]
# ### <font color="green"> _Task 1: Reading Files_ </font>
#
# 1. Read in the file `sum_elements.txt` and print each line. Does the result represent the content of the file?
# 1. Sum up all numbers in the file and calculate the average. Hint: As each line is a character string, you can not do computations with it, use the functions `int()` and or  `float()` to convert the strings to numbers.
# 1. Check the result by doing a manual calculation.

# %%
# Your Solution:

# %% [markdown]
# ## String Manipulation
# A very important task when working with strings is string manipulation, for which Python has sophisticated built-in functions.
#
# * `str.split(separator)`: Split a string using the separator character into a list of strings
# * `str.strip()`: Return a copy of the string with leading and tailing characters (whitespace, newline, tab) removed
# * `str.replace(old, new)`: Return a copy of string with all occurrences of substring old replaced by new.

# %%
# For example:
data_line = " 1,8; 2,5; 42,2\n"
print("example data line: ", data_line)

data_line_replace = data_line.replace(',','.')
print("replaced ',' by '.': ", data_line_replace)

data_line_strip = data_line_replace.strip()
print("strip: ", data_line_strip)

data_list_split = data_line_strip.split(';')
print("split by ';': ", data_list_split)

# %% [markdown]
# ### <font color="green"> _Task 2: Human Population_ </font>
#
# 1. Read in the file `human_population_2016.log` and print each line.
# 2. Modify each line (String-Manipulation) to print only the population per country. Hint: to access an individual element of a list, use the access operator `[]`. The first element has the index 0.
# 3. Sum up the population per country to calculate the world population.

# %%
# Your Solution.

# %% [markdown]
# ## Module glob
# It is in the nature of data analysis that a large number of data is often involved. To analyse a huge amount of data files, one should loop through each file automatically.
# The glob module finds all the pathnames matching a specified pattern and returns the file name.
#
# ### Modules in Python
# Although Python itself has only few build-in funcitons, its functionality can be extended with modules. To load a module, the `import` statement is used, followed by the module name. The functions provided by the loaded module are accessable as `modulename.functionname`.

# %%
# Example 1

import glob


# Print each file in current directory
for file in list(glob.glob('data*')):
    print(file)

# %%
# Example 2

# Print each file with the extension '.log' in each subdirectory.
# Here * is a wild card, that matches any characters
for file in sorted(list(glob.glob('weather_per_day/*.log'))):
    print(file.split('/'))

# %% [markdown]
# ### <font color="green"> _Task 3: Files_ </font>
#
# 1. Print each filename in the `weather_per_day` folder.
# 1. Print only filenames indicating data from November.

# %%
# Your Solution

# %% [markdown]
# ## If Statment
#
# In many cases the execution of commands is not fixed, but depends on a condition. For example, if you want to sum only positive numbers out of a set of integers, you would have to check if the current iteration value is positive. Depending on the outcome of this evaluation different code blocks will be executed. This is represented with `if` statements in Python.
#
# Python supports the following logical conditions from mathematics:
# - Equals: `a == b`
# - Not Equals: `a != b`
# - Less than: `a < b`
# - Less than or equal to: `a <= b`
# - Greater than: `a > b`
# - Greater than or equal to: `a >= b`

# %%
# Example:

sum_positiv = 0
for i in [3,8,-9,1,-3,8,3,-8,0,-4,-1]:
    if (i < 0 and i < -5) :
        print("found a {} negative number: {}".format(i,i+1))
        print("Test1 " + str(i) + " Test")
        sum_positiv = sum_positiv + i

print("sum of numbers: {}".format(sum_positiv))

# %% [markdown]
# ### <font color="green"> _Task 4: Weather Data_ </font>
#
# 1. Calculate the average temperture per day of the given data in the `weather_per_day` folder.
#    Hint: Possible approach:
#    - Iterate trhough each file using the `glob module` and a `for` loop
#    - Split and strip each line and sum up all temperatures.
#
#    - Divide the sum by the amount of iteration steps
#
#
# 1. Calculate the average temperture per day between 08:00 and 17:00.
#    To achieve this an extra module needs to be imported:
#
#    ```Python
#     from datetime import datetime
#     format = '%H:%M:%S' # Format time as seen in the weather file.
#
#     ```
#     To compare times, the time string in each file should be converted into a time type variable.

# %%
from datetime import datetime
format = '%H:%M:%S'
    
# Example:
    
time_string_current = '11:00:00' 
time_string_noon = '12:00:00'
time_current = datetime.strptime(time_string_current, format)
time_noon = datetime.strptime(time_string_noon, format)
   
if time_current < time_noon:
    print("Good morning")
else:
    print("Good afternoon")

# %% [markdown]
# Hint: To check if the data item is between to times, an if statement with two conditions is needed:
#
# ```python
#     if (condition_1 and condition_2):
#         do something
#     else:
#         do something different
#     ```

# %%
# Your solution
